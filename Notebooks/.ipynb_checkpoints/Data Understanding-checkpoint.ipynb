# %% [markdown]
# # Get Data from csv files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns


account = pd.read_csv("../data/raw/account.csv", sep=";")
card = pd.read_csv("../data/raw/card_dev.csv", sep=";")
client = pd.read_csv("../data/raw/client.csv", sep=";")
disposition = pd.read_csv("../data/raw/disp.csv", sep=";")
demograph = pd.read_csv("../data/raw/district.csv",sep=";")
loan = pd.read_csv("../data/raw/loan_dev.csv", sep=";")
transactions = pd.read_csv("../data/raw/trans_dev.csv",sep=";", low_memory=False)

# %% [markdown]
# # Merge Data

# %%
account_demograph = pd.merge(account, demograph, left_on="district_id", right_on="code ").drop("code ", axis=1)
loan_demograph = pd.merge(account_demograph, loan, on="account_id")

# %%
#Geting data from client/account/disposition/transactions/loan
client_account_trans = pd.merge(disposition,transactions, on = ['account_id', 'account_id'])
client_account_trans_loan = pd.merge(client_account_trans,loan, on= ['account_id', 'account_id'])

#cleaning data ?!?
client_account_trans_loan.drop("k_symbol", axis=1, inplace=True)
client_account_trans_loan.drop("account", axis=1, inplace=True)
client_account_trans_loan.drop("bank", axis=1, inplace=True)
client_account_trans_loan.drop("type_x", axis=1, inplace=True)
client_account_trans_loan.drop("disp_id", axis=1, inplace=True)
client_account_trans_loan.drop("account_id", axis=1, inplace=True)
client_account_trans_loan.rename(columns={"type_y": "type_transaction"}, inplace=True)
client_account_trans_loan.rename(columns={"amount_x": "amount_transaction"}, inplace=True)
client_account_trans_loan.rename(columns={"amount_y": "amount_loan"}, inplace=True)
client_account_trans_loan.rename(columns={"date_x": "date_transaction"}, inplace=True)
client_account_trans_loan.rename(columns={"date_y": "date_loan"}, inplace=True)
client_account_trans_loan.sort_values(by=['client_id','date_loan','date_transaction'])
#print(client_account_trans_loan.head(5))
# Out:
#        client_id  trans_id  date_transaction type_transaction  \
# 0              2       276            930226           credit
# 1              2       279            930312           credit
# 2              2       697            930328           credit
# 3              2   3530483            930331           credit
# 4              2       280            930412           credit
# ...          ...       ...               ...              ...
# 30368      13971   3424164            961206       withdrawal
# 30369      13971   3424358            961207       withdrawal
# 30370      13971   3424116            961207       withdrawal
# 30371      13971   3424068            961208       withdrawal
# 30372      13971   3424020            961210       withdrawal
#
#                           operation  amount_transaction  balance  loan_id  \
# 0                    credit in cash              1100.0   1100.0     4959
# 1      collection from another bank             20236.0  21336.0     4959
# 2                    credit in cash              3700.0  25036.0     4959
# 3                               NaN                13.5  25049.5     4959
# 4      collection from another bank             20236.0  45285.5     4959
# ...                             ...                 ...      ...      ...
# 30368    remittance to another bank               129.0  39765.5     7308
# 30369            withdrawal in cash             10400.0  29365.5     7308
# 30370    remittance to another bank               330.0  29035.5     7308
# 30371    remittance to another bank                56.0  28979.5     7308
# 30372    remittance to another bank              4780.0  24199.5     7308
#
#        date_loan  amount_loan  duration  payments  status
# 0         940105        80952        24      3373       1
# 1         940105        80952        24      3373       1
# 2         940105        80952        24      3373       1
# 3         940105        80952        24      3373       1
# 4         940105        80952        24      3373       1
# ...          ...          ...       ...       ...     ...
# 30368     961227       129408        24      5392       1
# 30369     961227       129408        24      5392       1
# 30370     961227       129408        24      5392       1
# 30371     961227       129408        24      5392       1
# 30372     961227       129408        24      5392       1
#
# [30373 rows x 13 columns]

# %% [markdown]
# # Graphics
# ### Histogram (Loan Amount)

# %%
plt.figure(figsize=(10, 7))

plt.xlabel('Loan Amount')
plt.ylabel('Nº Of Clients')
loan_amount = plt.hist(loan['amount'])
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(15, 8))

plt.xlabel('Loan Amount')
plt.ylabel('Average Salary')
salary_amount = plt.scatter(x=loan_demograph["average salary "], y=loan_demograph["amount"],)
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
dic = {}

for type in card["type"]:
    if type == "junior": 
        if type not in dic.keys():
            dic['junior'] = 1
        else:
            dic['junior'] += 1
    if type == "classic":
        if type not in dic.keys():
            dic['classic'] = 1
        else:
            dic['classic'] += 1
    if type == "gold":
        if type not in dic.keys():
            dic['gold'] = 1
        else:
            dic['gold'] += 1

            
plt.figure(figsize=(10, 8))
plt.pie(dic.values(), labels = dic.keys(), autopct='%1.1f%%')
plt.show()

'''           
plt.xlabel('Card Types')
plt.ylabel('Nº clients')            
plt.bar(dic.keys(), dic.values())
plt.show()
'''
# Out:
# "           \nplt.xlabel('Card Types')\nplt.ylabel('Nº clients')            \nplt.bar(dic.keys(), dic.values())\nplt.show()\n"

# %%
dic = {}

for type in transactions["type"]:
    if type == "credit": 
        if type not in dic.keys():
            dic['credit'] = 1
        else:
            dic['credit'] += 1
    if type == "withdrawal":
        if type not in dic.keys():
            dic['withdrawal'] = 1
        else:
            dic['withdrawal'] += 1
            

plt.figure(figsize=(10, 8))
            
plt.xlabel('Transaction Types')
plt.ylabel('Nº Transactions')            
plt.bar(dic.keys(), dic.values())
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
#loan_demograph 
corr_matrix = loan_demograph[["amount", "duration", "average salary ", "unemploymant rate '95 ", "unemploymant rate '96 ", "no. of enterpreneurs per 1000 inhabitants ", "no. of commited crimes '95 ", "no. of commited crimes '96 "]].corr()
corr_matrix.style.background_gradient(cmap='coolwarm')

plot_corr = sns.heatmap(corr_matrix, annot=True)

# %%
#client_account_trans_loan correlation matrix
corr_matrix_clnt_acnt_trs_loan = client_account_trans_loan[["client_id","date_transaction", "operation", "amount_transaction", "balance","date_loan", "amount_loan","duration", "payments", "status"]].corr()
corr_matrix_clnt_acnt_trs_loan.style.background_gradient(cmap='coolwarm')

plot_corr_matrix_clnt_acnt_trs_loan = sns.heatmap(corr_matrix_clnt_acnt_trs_loan, annot=True)
# Out:
# /tmp/ipykernel_30265/769962055.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_clnt_acnt_trs_loan = client_account_trans_loan[["client_id","date_transaction", "operation", "amount_transaction", "balance","date_loan", "amount_loan","duration", "payments", "status"]].corr()

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ### Account Table Missing Values

# %%
print(account.isnull().sum() / len(account))
# Out:
# account_id     0.0
# district_id    0.0
# frequency      0.0
# date           0.0
# dtype: float64

# %% [markdown]
# ### Card_dev Table Missing Values

# %%
print(card.isnull().sum() / len(card))
# Out:
# card_id    0.0
# disp_id    0.0
# type       0.0
# issued     0.0
# dtype: float64

# %% [markdown]
# ### Client Table Missing Values

# %%
print(client.isnull().sum() / len(client))
# Out:
# client_id       0.0
# birth_number    0.0
# district_id     0.0
# dtype: float64

# %% [markdown]
# ### Disp Table Missing Values

# %%
print(disposition.isnull().sum() / len(disposition))
# Out:
# disp_id       0.0
# client_id     0.0
# account_id    0.0
# type          0.0
# dtype: float64

# %% [markdown]
# ### District Table Missing Values

# %%
print(demograph.isnull().sum() / len(demograph))
# Out:
# code                                                 0.0
# name                                                 0.0
# region                                               0.0
# no. of inhabitants                                   0.0
# no. of municipalities with inhabitants < 499         0.0
# no. of municipalities with inhabitants 500-1999      0.0
# no. of municipalities with inhabitants 2000-9999     0.0
# no. of municipalities with inhabitants >10000        0.0
# no. of cities                                        0.0
# ratio of urban inhabitants                           0.0
# average salary                                       0.0
# unemploymant rate '95                                0.0
# unemploymant rate '96                                0.0
# no. of enterpreneurs per 1000 inhabitants            0.0
# no. of commited crimes '95                           0.0
# no. of commited crimes '96                           0.0
# dtype: float64

# %% [markdown]
# ### Loan_dev Table Missing Values

# %%
print(loan.isnull().sum() / len(loan))
# Out:
# loan_id       0.0
# account_id    0.0
# date          0.0
# amount        0.0
# duration      0.0
# payments      0.0
# status        0.0
# dtype: float64

# %% [markdown]
# ### Trans_dev Table Missing Values

# %%
print(transactions.isnull().sum() / len(transactions))
# Out:
# trans_id      0.000000
# account_id    0.000000
# date          0.000000
# type          0.000000
# operation     0.178381
# amount        0.000000
# balance       0.000000
# k_symbol      0.466980
# bank          0.754863
# account       0.742292
# dtype: float64
